# %% [markdown]
# # 文件读写相关测试

# %% [markdown]
# ## 测试Python写入API的性能

# %% [markdown]
# ### 测试环境
#
# 1. 芯片:
#
# 2. 内存：
#
# 3. 机械磁盘：
#
# 4. 固态硬盘：
#
# 5. Python版本:
#
# 6. Rust版本：

# %% [markdown]
# ### 代码
#
# [Python](./py/bm_fileio/bm_fileio/__main__.py)
#
# [Rust](./rs/bm_fileio/src/main.rs)

# %% [markdown]
# ### 结果
#
#
# | 磁盘类型 | 文件系统 | 程序语言     | 写入方式 | 每轮批量写入数据量（比特） | 每轮总共写入数据量（兆）| 测试轮数（次） | 第一次测试每轮平均耗时（秒)  | 第二次测试每轮平均耗时（秒) | 第三次测试每轮平均耗时（秒) |
# | -------- | -------- | ------------ | -------- | -------------------------- | ----------------------- | -------------- | ---------------------------- | --------------------------- | --------------------------- |
# | hdd      | xfs      | cpython      | 同步     | 1                          | 100                     | 3              | 440.6771201528609            | 439.0294273868203           |                             |
# | hdd      | xfs      | cpython      | 同步     | 1024                       | 100                     | 3              | 5.437702191993594            | 4.372969234362245   |                             |
# | hdd      | xfs      | cpython      | 异步     | 1                          | 100                     | 3              | 严重超时                     | 严重超时            |                             |
# | hdd      | xfs      | cpython      | 异步     | 1024                       | 100                     | 3              | 619.3807931654155            | 610.1238648183644   |                             |
# | hdd      | xfs      | rust         | 同步     | 1                          | 100                     | 3              | 1662.66                      |                     |                             |
# | hdd      | xfs      | rust         | 同步     | 1024                       | 100                     | 3              | 5.15                         |                     |                             |
# | hdd      | xfs      | rust         | 异步     | 1                          | 100                     | 3              | 33500.80                     |                     |                             |
# | hdd      | xfs      | rust         | 异步     | 1024                       | 100                     | 3              | 35.46                        |                     |                             |
# | ssd      | xfs      | cpython      | 同步     | 1                          | 100                     | 3              | 466.29305572248995           | 441.9375464692712   |                             |
# | ssd      | xfs      | cpython      | 同步     | 1024                       | 100                     | 3              | 2.6028894502669573           | 2.5658493880182505  |                             |
# | ssd      | xfs      | cpython      | 异步     | 1                          | 100                     | 3              | 严重超时                     | 严重超时            |                             |
# | ssd      | xfs      | cpython      | 异步     | 1024                       | 100                     | 3              | 619.9094696957618            | 625.1772190667689   |                             |
# | ssd      | xfs      | rust         | 同步     | 1                          | 100                     | 3              | 2683.81                      |                     |                             |
# | ssd      | xfs      | rust         | 同步     | 1024                       | 100                     | 3              | 3.34                         |                     |                             |
# | ssd      | xfs      | rust         | 异步     | 1                          | 100                     | 3              | 37804.47                     |                     |                             |
# | ssd      | xfs      | rust         | 异步     | 1024                       | 100                     | 3              | 38.84                        |                     |                             |
